# %% [markdown]
# # Emotion_Detection

# %% [markdown]
# Importing Libraries

# %%
import matplotlib.pyplot as plt
from glob import glob
import cv2
import random
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D 
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from IPython.display import SVG, Image
import tensorflow as tf
print("Tensorflow version:", tf.__version__)
# Out:
# Tensorflow version: 2.13.0

# %%
images = glob("train/**/**")
for i in range(9):
    image = random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));
    plt.axis('off')

# %% [markdown]
# # Preparing Data For Training

# %%
img_size = 48
batch_size = 64
datagen_train = ImageDataGenerator()
train_generator = datagen_train.flow_from_directory("train/",
                                                    target_size = (img_size,img_size),
                                                    color_mode = "grayscale",
                                                    batch_size = batch_size,
                                                    class_mode = "categorical",
                                                    shuffle = True)
datagen_validation = ImageDataGenerator()
validation_generator = datagen_train.flow_from_directory("test/",
                                                     target_size = (img_size,img_size),
                                                     color_mode = "grayscale",
                                                     batch_size = batch_size,
                                                     class_mode = "categorical",
                                                     shuffle = True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # Defining Model

# %%
def Convolution (input_tensor, filters, kernel_size):
    
    x = Conv2D(filters = filters, kernel_size = kernel_size, padding = "same") (input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size = (2,2))(x)
    x = Dropout(0.25)(x)
    
    return x

# %%
def Dense_f(input_tensor, nodes):
    
    x = Dense(nodes)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.25)(x)
    
    return x

# %%
def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = Convolution(inputs, 32, (3,3))
    conv_2 = Convolution(inputs, 64, (5,5))
    conv_3 = Convolution(inputs, 128, (3,3))
    flatten = Flatten()(conv_3)
    dense_1 = Dense_f(flatten,256)
    output = Dense (7, activation = "softmax")(dense_1)
    model = Model(inputs = [inputs], outputs = [output])
    model.compile(loss = ['categorical_crossentropy'], optimizer = 'adam', metrics = ["accuracy"])
    return model

# %%
model = model_fer((48,48,1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 128)       1280
#
#  batch_normalization_2 (Bat  (None, 48, 48, 128)       512
#  chNormalization)
#
#  activation_2 (Activation)   (None, 48, 48, 128)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 24, 24, 128)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 24, 24, 128)       0
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 256)               18874624
#
#  batch_normalization_3 (Bat  (None, 256)               1024
#  chNormalization)
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 18879239 (72.02 MB)
# Trainable params: 18878471 (72.02 MB)
# Non-trainable params: 768 (3.00 KB)
# _________________________________________________________________

# %% [markdown]
# # Initializing The Model

# %%
epochs = 15
steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps = validation_generator.n//validation_generator.batch_size

checkpoint = ModelCheckpoint ("model_weights.h5", monitor = 'val_accuracy', save_weights_only = True, mode = 'max', verbose =1)
callbacks = [checkpoint]

# %% [markdown]
# # Training The Model

# %% [markdown]
# This cell takes time to complete

# %%
history = model.fit(
x = train_generator,
steps_per_epoch = steps_per_epoch,
epochs = epochs,
validation_data = validation_generator,
validation_steps = validation_steps,
callbacks = callbacks)
# Out:
# Epoch 1/15
# 448/448 [==============================] - ETA: 0s - loss: 1.6486 - accuracy: 0.3780
# Epoch 1: saving model to model_weights.h5
# 448/448 [==============================] - 1099s 2s/step - loss: 1.6486 - accuracy: 0.3780 - val_loss: 1.8382 - val_accuracy: 0.3097
# Epoch 2/15
# 448/448 [==============================] - ETA: 0s - loss: 1.3572 - accuracy: 0.4879
# Epoch 2: saving model to model_weights.h5
# 448/448 [==============================] - 1129s 3s/step - loss: 1.3572 - accuracy: 0.4879 - val_loss: 1.6954 - val_accuracy: 0.3302
# Epoch 3/15
# 448/448 [==============================] - ETA: 0s - loss: 1.1919 - accuracy: 0.5560
# Epoch 3: saving model to model_weights.h5
# 448/448 [==============================] - 1040s 2s/step - loss: 1.1919 - accuracy: 0.5560 - val_loss: 1.5574 - val_accuracy: 0.4049
# Epoch 4/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0603 - accuracy: 0.6092
# Epoch 4: saving model to model_weights.h5
# 448/448 [==============================] - 1073s 2s/step - loss: 1.0603 - accuracy: 0.6092 - val_loss: 1.4380 - val_accuracy: 0.4593
# Epoch 5/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9377 - accuracy: 0.6565
# Epoch 5: saving model to model_weights.h5
# 448/448 [==============================] - 1080s 2s/step - loss: 0.9377 - accuracy: 0.6565 - val_loss: 1.5602 - val_accuracy: 0.4502
# Epoch 6/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8087 - accuracy: 0.7098
# Epoch 6: saving model to model_weights.h5
# 448/448 [==============================] - 1179s 3s/step - loss: 0.8087 - accuracy: 0.7098 - val_loss: 1.6545 - val_accuracy: 0.4145
# Epoch 7/15
# 448/448 [==============================] - ETA: 0s - loss: 0.7029 - accuracy: 0.7504
# Epoch 7: saving model to model_weights.h5
# 448/448 [==============================] - 958s 2s/step - loss: 0.7029 - accuracy: 0.7504 - val_loss: 1.4936 - val_accuracy: 0.4908
# Epoch 8/15
# 448/448 [==============================] - ETA: 0s - loss: 0.6057 - accuracy: 0.7855
# Epoch 8: saving model to model_weights.h5
# 448/448 [==============================] - 977s 2s/step - loss: 0.6057 - accuracy: 0.7855 - val_loss: 1.8133 - val_accuracy: 0.4520
# Epoch 9/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5161 - accuracy: 0.8215
# Epoch 9: saving model to model_weights.h5
# 448/448 [==============================] - 946s 2s/step - loss: 0.5161 - accuracy: 0.8215 - val_loss: 1.6603 - val_accuracy: 0.4715
# Epoch 10/15
# 448/448 [==============================] - ETA: 0s - loss: 0.4500 - accuracy: 0.8452
# Epoch 10: saving model to model_weights.h5
# 448/448 [==============================] - 926s 2s/step - loss: 0.4500 - accuracy: 0.8452 - val_loss: 1.7034 - val_accuracy: 0.5020
# Epoch 11/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3844 - accuracy: 0.8678
# Epoch 11: saving model to model_weights.h5
# 448/448 [==============================] - 968s 2s/step - loss: 0.3844 - accuracy: 0.8678 - val_loss: 1.8339 - val_accuracy: 0.4887
# Epoch 12/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3320 - accuracy: 0.8890
# Epoch 12: saving model to model_weights.h5
# 448/448 [==============================] - 941s 2s/step - loss: 0.3320 - accuracy: 0.8890 - val_loss: 1.8902 - val_accuracy: 0.4780
# Epoch 13/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3102 - accuracy: 0.8957
# Epoch 13: saving model to model_weights.h5
# 448/448 [==============================] - 908s 2s/step - loss: 0.3102 - accuracy: 0.8957 - val_loss: 1.8312 - val_accuracy: 0.4993
# Epoch 14/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2773 - accuracy: 0.9088
# Epoch 14: saving model to model_weights.h5
# 448/448 [==============================] - 895s 2s/step - loss: 0.2773 - accuracy: 0.9088 - val_loss: 2.2410 - val_accuracy: 0.4570
# Epoch 15/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2493 - accuracy: 0.9195
# Epoch 15: saving model to model_weights.h5
# 448/448 [==============================] - 1249s 3s/step - loss: 0.2493 - accuracy: 0.9195 - val_loss: 1.9384 - val_accuracy: 0.4787

# %% [markdown]
# # Model Evaluation

# %%
model.evaluate(validation_generator)
# Out:
# 113/113 [==============================] - 30s 265ms/step - loss: 1.9378 - accuracy: 0.4790
# [1.9378159046173096, 0.4789634943008423]

# %% [markdown]
# # Plotting Loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.legend(['Train', 'Validation'], loc = 'upper left') 
plt.subplots_adjust(top=1.0, bottom=0.0, right=0.95, left=0.0,hspace=0.25, wspace=0.35)

# %% [markdown]
# # Plotting Accuracy

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.legend(['Train', 'Validation'], loc = 'upper left') 
plt.subplots_adjust(top=1.0, bottom=0.0, right=0.95, left=0.0,hspace=0.25, wspace=0.35)

# %% [markdown]
# # Saving Model

# %%
model_json = model.to_json()
with open("model_a.json", "w") as json_file:
    json_file.write(model_json)
